# %%
import pandas as pd
df = pd.read_csv("data/unemployed_complete.csv",sep=",")

# %%
df
# Out:
#        Year     Month  District Code District Name  Neighborhood Code  \
# 0      2021   January              1  Ciutat Vella                  1
# 1      2021   January              1  Ciutat Vella                  2
# 2      2021   January              1  Ciutat Vella                  3
# 3      2021   January              1  Ciutat Vella                  4
# 4      2021   January              2      Eixample                  5
# ...     ...       ...            ...           ...                ...
# 26635  2013  December             10    Sant Martí                 70
# 26636  2013  December             10    Sant Martí                 71
# 26637  2013  December             10    Sant Martí                 72
# 26638  2013  December             10    Sant Martí                 73
# 26639  2013  December             99     No consta                 99
#
#                            Neighborhood Name  Gender      Demand_occupation  \
# ...

# %%
df = df[df["Demand_occupation"]=="Registered unemployed"]

# %%
df = df[df["Number"]!=0]
df
# Out:
#        Year     Month  District Code District Name  Neighborhood Code  \
# 0      2021   January              1  Ciutat Vella                  1
# 1      2021   January              1  Ciutat Vella                  2
# 2      2021   January              1  Ciutat Vella                  3
# 3      2021   January              1  Ciutat Vella                  4
# 4      2021   January              2      Eixample                  5
# ...     ...       ...            ...           ...                ...
# 26634  2013  December             10    Sant Martí                 69
# 26635  2013  December             10    Sant Martí                 70
# 26636  2013  December             10    Sant Martí                 71
# 26637  2013  December             10    Sant Martí                 72
# 26638  2013  December             10    Sant Martí                 73
#
#                                   Neighborhood Name  Gender  \
# 0                                          el Raval  Female
# ...

# %%
df.columns = ['Year', 'Month', 'District.Code', 'District.Name', 'Neighborhood.Code',
       'Neighborhood.Name', 'Gender', 'Demand_occupation', 'Total']

# %%
df.to_csv("data/clean datasets/unemployed_complete.csv",index=False)
