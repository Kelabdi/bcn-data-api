# %%
import pandas as pd
df = pd.read_csv("unemployed_complete.csv",sep=",")

# %%
df["District.Name"].unique()
# Out:
# array(['Ciutat Vella', 'Eixample', 'Sants-Montjuïc', 'Les Corts',
#        'Sarrià-Sant Gervasi', 'Gràcia', 'Horta-Guinardó', 'Nou Barris',
#        'Sant Andreu', 'Sant Martí', 'No consta'], dtype=object)

# %%
df = df[df["District.Name"]!="No consta"]

# %%
df
# Out:
#        Year     Month  District.Code District.Name  Neighborhood.Code  \
# 0      2021   January              1  Ciutat Vella                  1
# 1      2021   January              1  Ciutat Vella                  2
# 2      2021   January              1  Ciutat Vella                  3
# 3      2021   January              1  Ciutat Vella                  4
# 4      2021   January              2      Eixample                  5
# ...     ...       ...            ...           ...                ...
# 15074  2013  December             10    Sant Martí                 69
# 15075  2013  December             10    Sant Martí                 70
# 15076  2013  December             10    Sant Martí                 71
# 15077  2013  December             10    Sant Martí                 72
# 15078  2013  December             10    Sant Martí                 73
#
#                                   Neighborhood.Name  Gender  \
# 0                                          el Raval  Female
# ...

# %%
df.to_csv("unemployed_complete.csv",index=False)
